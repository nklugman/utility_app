# %%
import fiona 
import shapely.geometry

kenya_shape = fiona.open("../Kenya_sublocations/kenya_sublocations.shp")
shapefile_record = next(iter(kenya_shape))

# %%
for shape_rec in kenya_shape:
    if(shape_rec['properties']['SUBLOC']=='KIBISH'):
        print(shape_rec['id'])
# Out:
# 0

# %%
for shape_rec in kenya_shape:
    print(shape_rec['properties'])
# Out:
# OrderedDict([('AREA', 0.584), ('PERIMETER', 3.843), ('KENSL89G_', 2), ('KENSL89G_I', 2999), ('SUBLOC', 'KIBISH')])
# OrderedDict([('AREA', 0.125), ('PERIMETER', 1.913), ('KENSL89G_', 3), ('KENSL89G_I', 3000), ('SUBLOC', 'LOTIKIPI')])
# OrderedDict([('AREA', 0.131), ('PERIMETER', 1.699), ('KENSL89G_', 4), ('KENSL89G_I', 2998), ('SUBLOC', 'LOITANIT')])
# OrderedDict([('AREA', 0.083), ('PERIMETER', 1.335), ('KENSL89G_', 5), ('KENSL89G_I', 2997), ('SUBLOC', 'KOKURO')])
# OrderedDict([('AREA', 0.09), ('PERIMETER', 1.364), ('KENSL89G_', 6), ('KENSL89G_I', 2996), ('SUBLOC', 'TODONYANG')])
# OrderedDict([('AREA', 0.191), ('PERIMETER', 1.872), ('KENSL89G_', 7), ('KENSL89G_I', 3001), ('SUBLOC', 'NANAM')])
# OrderedDict([('AREA', 0.064), ('PERIMETER', 1.643), ('KENSL89G_', 8), ('KENSL89G_I', 3004), ('SUBLOC', 'LOKANGAE')])
# OrderedDict([('AREA', 0.099), ('PERIMETER', 1.725), ('KENSL89G_', 9), ('KENSL89G_I', 3005), ('SUBLOC', 'KAALING')])
# ...

# %%
print(shapefile_record)

# %%
print(shapefile_record['properties']['SUBLOC'][OrderedDict])

# %%
print(shapefile_record)
