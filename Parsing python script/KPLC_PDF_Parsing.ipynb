# %%
import os
import PyPDF2
import re
import psycopg2
import sys
import datetime

def walk_dir(dir,fileinfo,topdown=True):
    for root, dirs, files in os.walk(dir, topdown):
        for name in files:
            fileinfo.write(os.path.join(root,name) + '\n')

def parseTime(_time):
    hour_break=re.search('(?=[0-9]+)',_time).end()
    _time=_time[hour_break:]
    hour_break=re.search('[0-9]+',_time).end()
    hour=_time[:hour_break].strip()
    _time=_time[hour_break+1:]
    minute_break=re.search('[0-9]+',_time).end()
    minute=_time[:minute_break].strip()
    _time=_time[minute_break:]
    time=hour+':'+minute+' '
    if _time.find("A")!=-1:
        time+='AM'
    else:
        time+='PM'
    return time
            
def parse(directory,cur):
    lists=[]
    r = ""
    start_time=""
    end_time=""
    pdfFileObj = open(directory, 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    num_pages = pdfReader.numPages
    for i in range(num_pages):
        pageObj = pdfReader.getPage(i)
        text = pageObj.extractText()

        text = text.replace("\n","")
        text = text.replace("Œ","-")
        text = text.replace("™","'")
        text = text.replace("˚","ffi")
        text = text.replace("˛","ff")
        text = text.replace("˜","fi")
        text = text.replace("˝","fl")

        content=text.split("Notice is hereby ")
        for j in range(len(content)):
            if j == 0:
                regions  = re.split("((?:[A-Z])(?:[A-Z|\.]+\s)+(?:REGION))", content[0])
            else:
                content=content[1].split("etc.)")
                regions  = re.split("((?:[A-Z])(?:[A-Z|\.]+\s)+(?:REGION))", content[1])

            for region in regions:
               if region.find("REGION")!=-1:
                   r = str(region)
               else:
                  area_ints = re.split("AREA:",region)
                  for area_int in area_ints:
                      areas = area_int.split("& adjacent customers.")
                      for area in areas:
                         area=area.strip()
                         if area.find("COUNTY")==-1 and len(area)>1:
                            try:
                                data = area
                                a=""
                                date=""
                                time=""

                                area_break = data.index("DATE")
                                a = data[:area_break].strip()
                                data = data[area_break+len("DATE:"):]

                                date_break = data.index("TIME")
                                date = data[:date_break].strip()
                                data = data[date_break+len("TIME:"):]

                                day_break=re.search('(?=[0-9]+)',date).end()
                                date=date[day_break:]
                                date_=date.split(".")
                                day = date_[0].strip()
                                month = date_[1].strip()
                                year = date_[2].strip()
                                year_break=re.search('[0-9]+',year).end()
                                year = year[:year_break].strip()
                                date=year+'-'+month+'-'+day

                                time_break = re.search('(A\.M|P\.M).*(A\.M|P\.M(\.)?)', data).end()
                                times = data[:time_break].strip()
                                data = data[time_break:]
                                start_time=""
                                end_time=""
                                
                                time=re.split("-|Š",times)
                                start_time=parseTime(time[0])
                                end_time=parseTime(time[1])
                                
                                areas_=a.split(",")
                                for area_ in areas_:
                                     if re.search('PART OF|PARTS OF|WHOLE OF',area_):
                                            area__break=re.search('PART OF|PARTS OF|WHOLE OF',area_).end()
                                            area_=area_[area__break:].strip()
                                     list = []
                                     list.append(date)
                                     list.append(start_time)
                                     list.append(end_time)
                                     list.append(r)
                                     list.append(area_.strip())
                                     for j in range(len(list)):
                                         if list[j]=="":
                                            list[j]=None
                                     
                                     length=""
                                     date_time=date+" "+start_time
                                     start=datetime.datetime.strptime(date_time,"%Y-%m-%d %I:%M %p")
                                     date_time=date+" "+end_time
                                     end=datetime.datetime.strptime(date_time,"%Y-%m-%d %I:%M %p")
                                     length=end-start
                                     list.append(length)
                                     lists.append(list)

                            except Exception as e:
                                print(e)
                                print(directory)
                                print(area)
                                print("----------------------------")
    pdfFileObj.close()
    return lists
                                    
dir = r'C:\GridWatch\Parsing service interruptions\Readable pdfs' #dir of folder
fileinfo = open('C:\\GridWatch\\Parsing service interruptions\\test2.txt','w')
walk_dir(dir,fileinfo)
fileinfo.close()

f = open('C:\\GridWatch\\Parsing service interruptions\\test2.txt','r')
#o = open('C:\\GridWatch\\Parsing service interruptions\\list1.txt','w')
#con = psycopg2.connect(database='outage_map', user='postgres') 
con = psycopg2.connect(database='capstone', user='capstone', password='capstone', host='141.212.11.206', port='5432')
con.autocommit = True
cur = con.cursor()
cur.execute("DROP TABLE IF EXISTS outages")
cur.execute("CREATE TABLE outages(index SERIAL PRIMARY KEY)")
cur.execute("ALTER TABLE outages ADD date date")
cur.execute("ALTER TABLE outages ADD start_time time")
cur.execute("ALTER TABLE outages ADD end_time time")
cur.execute("ALTER TABLE outages ADD region text")
cur.execute("ALTER TABLE outages ADD area text")
cur.execute("ALTER TABLE outages ADD length interval")
outages=[]
for line in f:
    directory = line.replace("\n","")
    lists = parse(directory,cur)
    for element in lists:
        outages.append(element)
try:
    dataText = ', '.join(map(bytes.decode,(cur.mogrify('(%s, %s, %s, %s, %s, %s)', element) for element in outages)))
    cur.execute('INSERT INTO outages (date,start_time,end_time,region,area,length) VALUES ' + dataText)
except Exception as e:
    print(e)
    print(element)
    print("----------------------------")
f.close()
#o.close()
con.commit()
print("finish")
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\02.05.2013.pdf
# flflflflflfl
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\02.05.2013.pdf
# fl
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\02.05.2013.pdf
# fl
# ----------------------------
# time data '201-10-09 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\03.10.2013.pdf
# WHOLE OF KABATI MARKET, KAGUNDU-INIDATE: Wednesday 09.10.201 TIME: 9.00 A.M. - 5.00 P.M.Kandara Market, Mithi, Makenji, Ria-Ndegwa, Kinyoho, Kamunyaka, Gaichanjiru, Thagari, Turuturu, Kagira, Githima, Ngurwe-ini, Manju, Kagumo-ini, Githunguri, Kariua, Mutitu, Mathare-ini, Mungaria, Rwathe, Gitaimbuka, Mukuria, Kibage, Kaguthi, Kamurugu, Ha-Charagu, Gakui, Karima-Mwaro, Kiiri
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\07.11.2013.pdf
# ffffffffff
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\09.05.2013.pdf
# fi
# ----------------------------
# time data '13-05-17 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\09.05.2013.pdf
# DAM ESTATE, NYAYO HIGHRISE, SOUTHLANDS ESTATEDATE: Friday 17.05.13  TIME: 9.00 A.M. - 5.00 P.M.Part of Langata Rd, Wilson Airport, Langata Prison, Part of Mbagathi Rd, Ngei Est, Memorial Hosp, IDH, Sunshine Sch
# ----------------------------
# time data '013-052-15 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\09.05.2013.pdf
# EVEREST FARM, AUTHI, BRADE GATE, THUNGARIDATE: Wednesday 15.052.013  TIME: 9.00 A.M. - 3.00 P.M.Gatuamba School, Kalicheni, Kwa Jei, Everest Farm, Aguthi, F.Maina, Brade Gate Industry, Kings Medical College, Safaricom/Celtel Sites, Thungari Bore Hole, Kigera Farm, Min of Agriculture Workshop, Mt.Carmel School, Solio Villages
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\09.05.2013.pdf
# fi
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\11.07.2013.pdf
# Mt
# ----------------------------
# list index out of range
# C:\GridWatch\Parsing service interruptions\Readable pdfs\12.09.2013.pdf
# TINGWANG'I, BONDO TOWN, BAR CHANDODATE: Wednesday 18 09.2013  TIME: 8.00 A.M. - 4.30 P.M.Ting Wang'i Mkt, Nyajuok Sec Sch, Part of Bondo University, Swetel Hotel, Sibo Water Pump, Sinapanga Pri Sch, Bondo Town, Bondo Township Sec Sch, Nyangoma Mission, Nango, Olango Beach, Liunda Beach, Sirango Beach, Lwak Mission, Ajigo Mkt, Gobei, Lwanda Kotieno, Bar Chando, Part of Ndori, Opoda Farm
# ----------------------------
# list index out of range
# C:\GridWatch\Parsing service interruptions\Readable pdfs\12.09.2013.pdf
# ELEMENTAITA, KIAMBOGO, MAU NAROK, TIPISDATE: Wednesday 18 09.2013  TIME: 9.00 A.M. - 5.00 P.M.Whole of Barnabas Centre, J B Drilling, Mzee Wa Nyama, Lake Nakuru Lodge, Dalamere Girls, Elementaita, Kiambogo, Kongasis, Kiptangwenyi, Mti Mingi, Mugaa Sec Sch, Kianjoya, Mau Narok, Fontana Mau (Flower Farm), Likia, Mathangauta, Tipis Safaricom (Tipis), Mwisho Wa Lami Centre, Sansora Farm, Olropil, Topot
# ----------------------------
# list index out of range
# C:\GridWatch\Parsing service interruptions\Readable pdfs\12.09.2013.pdf
# KABARAK EX RONGAIDATE: Wednesday 18 09.2013  TIME: 8.30 A.M. - 4.30 P.M.African Blooms, Bomasan, Part of Rosetto Flowers, Chemusian Farm, Gicheha Farm Jogoo House, Ex Margaret Farm, Wheat Field Girls, Kirobon, Miti Moja, Sobea, Shantara Flowers
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\14.11.2013.pdf
# fi
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\15wx5hOcX2Co_Interruptions 05.06.2014.pdf
# GITUGI, KARUGIA, NYAKAHURADATE: Thursday 12.06.2014  TIME: 900 A.M. - 5.00 P.M.Karugiamkt, Iyego Sec School, Kangema High School, Gitugi Mkt   & Sec School, Kanorero Mkt, Yakarengo Mkt, G3 Mkt, Michuki  Technical College, Mununga Mkt & Sec School, Gaturi Girls, Mugeka Mkt Bishop Mahiani Residence, Nyakihai
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\16.05.2013.pdf
# Mt
# ----------------------------
# time data '013-08-25 8:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\22.08.2013.pdf
# WHOLE OF KISUMU TOWN DATE: Sunday 25.08.013  TIME: 8.00 A.M. - 5.00 P.M.Whole of Kisumu town including United Silos Depot, Kenya Power Depot, Maseno University, Kisumu International Airport, KEMRI, Ahero, Rabuor, Ober Kamoth, Otonglo Mkt, Kima Mission, Emusire High Sch, Nyahera, Marine Police, Whole of Obote Rd, United Millers, Kenya Brewery, Kenya Pipe Line, Kisumu Resort, Coca-Cola, Fisheries, Public Works, KIE, Usoma Beach, Sabuni Rd & MRM, Sea Food, Afro Meat, Mombasa Millers, Swan Millers, M/S Tiley Foamat, New Nyanza Hosp, Aga Khan Hosp, Kibuye MKT, United Mall, Nakumatt City, Manyatta, Kibos area, Ndugu Quarry, Kisumu Concrete, Mamboleo Est, Riat, Kiboswa, Tigoi, Jebrock, Kondele, Kenya RE, Migosi, BOC, KPA, Lake Basin Rice, Arina Estate
# ----------------------------
# time data '013-08-28 8:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\22.08.2013.pdf
# KAYUCHO, MARANDA, GOT MATARDATE: Wednesday 28.08.013  TIME: 8.00 A.M. - 4.30 P.M.Kayucho Mkt, Nyamira Village, Maranda High Sch & Mkt, Agwara Mkt, Husi Mkt, Got Matar, Usenge Mkt, Osieko Beach, Got Ramogi, Jusa Sec, Uhanya Beach, Namonye Mkt & Mission, Bar Kanyango
# ----------------------------
# time data '201-10-18 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\5QRXadf8WmqO_Interruptions 15.10.2015.pdf
# MATUU & ENVIRONSDATE: Sunday 18.10.201% TIME: 9.00 A.M. - 5.00 P.M.Matuu Town, Wanziru, Kivingoni, Ikaatini, Kyasioni, Sofla, Ndalani, Maiuni, Kalukuni, Kimangu, Kisiiki, Kambimawe, Matangini, Klaatu &  adjacent customers.
# ----------------------------
# list index out of range
# C:\GridWatch\Parsing service interruptions\Readable pdfs\7Zrb5Gv1QJHU_Interruptions - 29.09.2016.pdf
# MENYINKWA, SUNEKA, BOTORODATE: Wednesday 05.10 2016                               TIME: 8.00 A.M. - 5.00 P.M.Menyinkwa, Pope Benedict Sch, Masongo Dispensary, Nyamolewa Sec Sch, Surich Academy, Bunyaoro Sec Sch, Riotachi Dipensary, Kiabusura Academy, Bonyaoro, Otamba Mkt & Sch, Gesure, Itibo, Botoro Sec Sch
# ----------------------------
# time data '2014-05-20, Thursday 22 & Saturday 24 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\8oWBamcGb5q1_Interruptions 15.05.2014.pdf
# WHOLE OF LIKONI, MTONGWEDATE: Tuesday 20, Thursday 22 & Saturday 24.05.2014TIME: 9.00 A.M. - 5.00 P.M.Kenya Navy, Likoni District Hosp, Likoni Police Mweza, Keydee, Moi Forces Sch, Whole of Mtongwe, Centre NYS, Pungu Villas, Tijara, Ngombeni Slaughter, Shikaadabu, Kitije, Majengo Mapya, Approved Sch, Mbuta Hosp, Kiteje
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\9HHFRu7oc1Fh_Interruptions 19 05 2016.pdf
# fifififififififififififififififififififififififififififi
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\9HHFRu7oc1Fh_Interruptions 19 05 2016.pdf
# fi fifififififififififififififififififififififififififififififififififififififififififififi
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\cdWpNfVKtKrk_Interruptions 15.01.2015.pdf
# KIAMBU ROAD, RIDGEWAYS, THINDIGUA, MUTHITHIDATE: Saturday 17.01.2015  TIME: 600 A.M. - 6.00 P.M.Ridgeways Nakumatt, Ridgeways Rd, Kigwa Farm, Suraya Estate, St Mary School, Thindigua Village, GG Thindigua, Mushroom, Eden Ville Estate, Kugeria Estate, Muthithi Village, Njatha Ini Rd, Valentine Flower, Starehe Girls, Ngomongo  Village, Part Mirema Drive, Kiambu High School, Fairview Estate, Kamiti Rd, Kigutha Farm, Kiu Kenda Farm, Mugumo Estate
# ----------------------------
# time data '201-01-21 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\CXDhd5l02vXh_Interruptions 14.01.2016.pdf
# EASTERN BYPASSDATE: Thursday 21.01.201 TIME: 9.00 A.M. - 2.00 P.M. Part of Eastern Bypass, Syzo Ltd International
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\CXDhd5l02vXh_Interruptions 14.01.2016.pdf
# THIKA SECTION 9 ESTATE, TUSKYS CHANIADATE: Sunday 17.01.2016 TIIME: 9.00 A.M. - 5.00 P.M.Part of Thika Section 9 Est, Thika Nursing Home, Tuskys Chania, Mater Hosp - Thika, Coconut Grill Hotel, Shell Petro Stn - Gatitu
# ----------------------------
# time data '15-02-12 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\fIqqezu8lCk9_Interruptions 05.02.2015.pdf
# PART OF JAMES GICHURU ROADDATE: Thursday 12.02.15  TIME: 9.00 A.M. - 5.00 P.M.Mzima Springs, Part of James Gichuru, Manyani Rd, Riverside Drive, Strathmore Sch, Muthangari Police Stn, Apple Close, Kabarserian Rd
# ----------------------------
# time data '15-02-11 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\fIqqezu8lCk9_Interruptions 05.02.2015.pdf
# UPPERHILLDATE: Wednesday 11.02.15  TIME: 9.00 A.M. - 5.00 P.M.Upperhill Rd, Part of Mara Rd, Rahimtula
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\GhDZVlFNxtVO_Interuptions 29.10.2015.pdf
# RHAPTA FEEDERDATE: Saturday 31.10.2015  TIME: 9.00 a.m. - 5.00 p.m.Raphta Rd, East Church Rd, Rehema Hse, Part of Westlands Avn, St. Michaels Rd, Mahiga Mairu Rd, Pride Inn Hotel, Lantana Rd, Part of Saitoti Rd, Sports Rd, David Osieli, Mvuli Rd
# ----------------------------
# time data '20-06-21 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\h3QqcDqcVz2c_Interruptions 16 06 2016.pdf
# KIAMUNYI, MANGU, KABARAK, LENGENETDATE: Tuesday 21.06.20 TIME: 9.00 A.M. - 3.00 P.M.Whole of Olive Inn, Mercy Njeri, Martugada, Whole of Mang'u, Lengenet, Boito, Rawhide, Kabarak Univ & Sch, Hon Moi Residence, Kabarak Dairy & Hatcheries, Ra˙ki Farm, Oloika Hotel, Kampi ya Moto Centre, Gitau Centre, Olrongai Centre, Morop Girls
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\h3QqcDqcVz2c_Interruptions 16 06 2016.pdf
# ffi
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interrruptions_24.01.2013.pdf
# JUJA FARM NYACABA, MARABADATE: Thursday 31.01.2013 Time 9.00 A.M. - 4.00 P.M.Chania Mines Quarry, Odmark Quarry, Kimuchu Maraba, Kimuchu Bore Hole, Muthara Dispensary, Kalimoni Sisal, Mama Mumbi Resdent/Bore Hole, KPP Flower Farm, Abba Salama Sch, Kwa Murage, Athi Dispensary, Juja Farm White House, Gikumari
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions - 24.11.2016.pdf
# BAHATI, COLOR CROPS DATE: Saturday 26.11.2016fififififififififififififififififififi fifififi        TIME: 9:00 AM - 5:00 P.M.Whole of Bahati Centre, Jomo Kenyatta High Sch, Color Crops, Part of
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions - 24.11.2016.pdf
# fi
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_06.03.2014.pdf
# WHOLE OF KINANGOP DATE: Tuesday 11.03.2014 TIME: 10.00 A.M. - 5.00 PM.The Whole of N/Kinangop & S/Kinangop Including Geta, Bush Center, Live Wire Flower Farms, Olij Flower Farm, Kipipiri Flowers, Engineer Town, Ndunyu Njeru Town, Tuso Milk Processes, Kinangop Catholic Hosp, Mukimuki Milk Processes, Njabi-Ini Town, Kirima Centre, Mawingo Town, Rironi Centre, Miharati Town, Wanjohi Town, Murungaru Centre, Kwa Haraka Centre, Karangatha Centre, Karima Girls High Sch, Mumui Sec Sch, Ndinda Centre, Machinery Centre, Kinamba Centre, Maraigushu Centre, Nyodia Centre & Wanjohi Milk Processing, Kinamba Center, Karati Center, NYS, Munyaka, Chobe, Kijiko Midland, Muhoti Milk Processors, Kinja Trading Centre
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_06_03_2014.pdf
# WHOLE OF KINANGOP DATE: Tuesday 11.03.2014 TIME: 10.00 A.M. - 5.00 PM.The Whole of N/Kinangop & S/Kinangop Including Geta, Bush Center, Live Wire Flower Farms, Olij Flower Farm, Kipipiri Flowers, Engineer Town, Ndunyu Njeru Town, Tuso Milk Processes, Kinangop Catholic Hosp, Mukimuki Milk Processes, Njabi-Ini Town, Kirima Centre, Mawingo Town, Rironi Centre, Miharati Town, Wanjohi Town, Murungaru Centre, Kwa Haraka Centre, Karangatha Centre, Karima Girls High Sch, Mumui Sec Sch, Ndinda Centre, Machinery Centre, Kinamba Centre, Maraigushu Centre, Nyodia Centre & Wanjohi Milk Processing, Kinamba Center, Karati Center, NYS, Munyaka, Chobe, Kijiko Midland, Muhoti Milk Processors, Kinja Trading Centre
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_10.01.2013.pdf
# PART OF MUTHAIGADATE: Friday 11.01.2013  TIME: 8.00 A.M. - 5 P.M.Muthaiga Road, Orchard Close, Serengeti Avenue, Mobil Plaza, Kiambu Road, Kenya Forest Service, C.I.D Hqtrs
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_13.03.2014.pdf
# fi fi
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_16.01.2014.pdf
# Factory, Kangari Mkt, Kigumo Mkt, Githambo T/Factory, Kangema Town, Kanyenyaini Tea Factory, Karatu, Gakoe, Gitwe, Kanyoni, Gatura, Kimandi, Ndekei, Ngorongo, Kangari, Muthithi, Githambo, Hon SK Macharia's Residence, Githambo Tea Factory, Mugoiri Sch & Mission, Njumbi High Sch, Iyego, Gakurwe Mkt
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_16.01.2014.pdf
# fl
# ----------------------------
# time data '13-07-26 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_17.07.2013.pdf
# NYARI ESTATEDATE: Friday 26.07.13  TIME: 9.00 A.M. - 5.00 P.M.  Nyari Estate, Egrets Drive, Ibis Drive, Ibis Crescent, Nyari Police, Hosp Hill Sec Sch, Redhill Drive, Thigiri Farm, Part of Thigiri Ridge Rd
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_17.07.2013.pdf
# NGORIKA, TUMAINI, DUNDORIDATE: Tuesday 23.07.2013  TIME: 9 A.M. - 2.00 P.M.Wanyororo, Tabuga, Danger, Whole of Dundori, Nyakiambi Sec Sch & Mkt, Ngorika, Nyadundo Repeater Stn, Milangine, Tumaini, Beef Research, Woria Centre, Kwa Kiongo Centre
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_30.01.2014.pdf
# PART OF NAIVASHA ROADDATE: Thursday 06.02.2014  TIME: 9.00 - 5.00 P.M.Part of Gitanga Rd, Hatheru Rd, Kingara Rd, Part of Riara Rd, Riara Close, Mbaazi Ave, Kawangware, Part of Ndwaru Rd, Gathondeki, Precious Blood Riruta
# ----------------------------
# day is out of range for month
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Interruptions_30.01.2014.pdf
# MAWAWA MARKET, GEKONGEDATE: Thursday 30.02.2014  TIME: 9.00 A.M. - 3.00 P.M.Mawawa Mkt, Gekonge Sec/Mkt, Esamba Mkt, Riomego Mkt
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\iYdnEFpu5Yoz_Interruptions 08.10.2015.pdf
# SOBEA, GICHEA FARM, PART OF RONGAIDATE: Friday, 09.10.2015 TIME: 8:00AM - 1:00 PMPart of Salgaa Town Centre, Sobea, Santara, Chemusian Farm, Miti Moja, African Blooms, Loseto Flowers, Gicheha Farm, Boma San
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\iYdnEFpu5Yoz_Interruptions 08.10.2015.pdf
# PART OF SECTION 58, NAKA, NAKURUDATE: Sunday 11.10.2015 TIME: 8.00AM - 5:00 P.M.Paul Machanga, Kisulisuli, Section 58 Est, Lower Part of Nakuru Town, Egerton University, Bedi Investment, Londra
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\KfydxoHdpHiY_Interruptions 28 04 2016.pdf
# PART OF NEW MOMBASA-MALINDI RD DATE: Tuesday 03.05.2016  TIME: 9.00 - 5.00 P.M.Kangi, Makaburini, Superbandika Bakery, Part of Kongowea Mkt
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\KfydxoHdpHiY_Interruptions 28 04 2016.pdf
# PART OF NYALI, BOMBOLULU DATE: Friday 06.05.2016  TIME: 9.00 - 5.00 P.M.Harambee Est, Mamba Village, Mamba Round About, Nyali Golf, Twiga Villas, Broadway Street, Beach Rd
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\KfydxoHdpHiY_Interruptions 28 04 2016.pdf
# fiPART OF UKUNDA, DIANI BEACHDATE: Tuesday 03.05.2016  TIME: 9.00 - 5.00 P.M.Rongai Butchery, Ukunda Corner, Equity, Palm Beach Hosp, KPLC Ukunda Office, Nakumatt Diani, Kaskazi, Diani Shopping Centre, Two Fishes
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Kipevu_Power_Interruption_Notice.pdf
# POWER INTERRUPTION NOTICEKenya Power will interrupt electricity supply to Kipevu Hilltop Substation on Thursday 5th December, 2013. Arrangements are being made to transfer as many customers as possible to alternative substations and feeders to minimize interruption. Despite these efforts, some customers living in and adjacent areas shown below will be affected. The Company regrets any inconvenience that may be caused during the operation.
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Kipevu_Power_Interruption_Notice.pdf
# www.kenyapower.co.ke
# ----------------------------
# time data '15-11-16 9:00 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\KqzIEUNg4Csc_Interruptions 12.11.2015.pdf
# PART OF JAMES GICHURU ROADDATE: Monday 16.11.15 TIME: 9.00 A.M. - 5.00 P.M. Kingara Rd, Part of Gitanga Rd, Part of James Gichuru Rd, Hatheru Rd, Mbaazi Ave
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\kSp1G6quVsxj_Interruptions 02 06 2016  .pdf
# fififi
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\l5mATCURqeaK_Interruptions - 20.10.2016.pdf
# NGANO FACTORY, ELDORET QUARRYDATE: Sunday 23.10.2016                                           TIME: 9.00 A.M. - 4.00 P.Kamoret, Kamagut, Eldoret Quarry, Kipkeino Mkt, Ngano Factory
# ----------------------------
# time data '2014-09-02 13:00 PM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Np16kxWI2Dru_Interruption Notices 28.08.2014.pdf
# KAPSOYA, ILLULADATE: Tuesday 02.09.2014 TIME: 8.30 A.M. - 13.00 P.M.Kapsoya Estate, Illula Pri, Illula Sec, Sayare, Limo Hospital, Radio Africa, Jaggir Sing, Beliomo Farm
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Np16kxWI2Dru_Interruption Notices 28.08.2014.pdf
# KAKEMER, MODINGDATE: Friday 29.08.2014 TIME: 10 A.M. - 12.00 P.M.Part of Kawalun Mkt, Kakemer Boarding & Mixed Secondary Schools Kakemer Mkt, Moding Mkt, Moding Boarding High School, Kolait School
# ----------------------------
# time data '2014-08-31 15:00 PM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Np16kxWI2Dru_Interruption Notices 28.08.2014.pdf
# MILIMANI, C.B.D KISUMU CITYDATE: Sunday 31.08.2014 TIME: 9.00 A.M. - 15.00 P.M.Nakumat City Centre Supermarket, Maseno University, KNA Building, Re-insurance Plaza, Kisumu Hotel, County Hqtrs, New Kisumu Uchumi Supermarket, Central Bank, KCB Law Courts, Gulf Stream Busia Road
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Np16kxWI2Dru_Interruption Notices 28.08.2014.pdf
# WHOLE OF NYAMIRADATE: Monday 01.09.2014 TIME: 800 A.M. - 4.00 P.M. Ikonge Mkt, Sotik Highland Factory, Kerito Factory, Ekerenyo Mkt, Nyaramba Mkt, Sanganyi Factory, Itibo Mkt, Nyamira Town, Kebirigo Mkt, Kebirigo Factory, Sironga Mkt, Mabundu Mkt, Nyamaiya Mkt, Miruka Mkt, Masosa Mkt, Nyamusi Mkt, Manga Isecha, Nyabioto Mkt, Mosobeti Mkt, Nyapara Ibere, Mokomoni Mkt, Enchoro, Obwari Mkt, Nyagokiani, Borabu Hills, Kegogi Mkt, Makairo, Nyachogochogo, Nyakemincha, Gucha, Nyamira Hospital, Nyaikuro Sec/Mkt, Tinga Mkt, Nyachururu Sec, Gianchore Factory
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\OhcqkdScsIUG_Interruptions_06.03.2014.pdf
# WHOLE OF KINANGOP DATE: Tuesday 11.03.2014 TIME: 10.00 A.M. - 5.00 PM.The Whole of N/Kinangop & S/Kinangop Including Geta, Bush Center, Live Wire Flower Farms, Olij Flower Farm, Kipipiri Flowers, Engineer Town, Ndunyu Njeru Town, Tuso Milk Processes, Kinangop Catholic Hosp, Mukimuki Milk Processes, Njabi-Ini Town, Kirima Centre, Mawingo Town, Rironi Centre, Miharati Town, Wanjohi Town, Murungaru Centre, Kwa Haraka Centre, Karangatha Centre, Karima Girls High Sch, Mumui Sec Sch, Ndinda Centre, Machinery Centre, Kinamba Centre, Maraigushu Centre, Nyodia Centre & Wanjohi Milk Processing, Kinamba Center, Karati Center, NYS, Munyaka, Chobe, Kijiko Midland, Muhoti Milk Processors, Kinja Trading Centre
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\OhcqkdScsIUG_Interruptions_13.03.2014.pdf
# fi fi
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\pNgPxCdzXUBm_Interuptions 25.02.2016.pdf
# PANDA FEEDER DATE: Wednesday 02.03.2016 TIME: 9.00 AM. - 3.00 P.M.Whole of Panda Flowers, Business Park, Kenchic Naivasha, Part of Delamare Pivot, Malu Hotel, Dairy Training Institute, Interplant Farm, Pima Ltd, Chapachula, Maridadi Flowers, Bigot Flowers
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\s8MGR4lPpPs4_Interruptions 20.11.2014.pdf
# DCK, OSERIAN, OLKARIADate Sunday 23.11.2014 TIME: 8.30 A.M. - 5.00 P.M.Whole of DCK including Vegro Farm, Finlay Kingflsher, Rift Farm, Vadenbarg Farm, Longonot Hortculture & Longonot Farm, Kedong Farm, Finley, Flamingo, Nini Farm, Kamuta Farm, Sanctuary Farm, Sopa Lodge, Sawela Lodge, Simba Lodge, Sir Karuturi Farm, Sera Farm, Kentaria, Double Dutch, Agri, Bio Ltd, Orpower Housing Estate, Kengen Houses, Fish Eagle, Kwamuya Centre, Kamere Centre, Whole of Oserian Both 33Kv & 11kV, Whole of Olkaria, Kongoni Centre, Maela Entre, DURU Farm, Aquila Farm, Kijambe Ltd, Ndabibi Centre, Hindu Farm, Crater Lake, Hippo Point, Kinja Estate, Kongoni Lodge, Tharau area, Mirera area, Longonot Gate
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\SiJZCKltLh6S_Interuptions 28.05.2015.pdf
# NAIVASHA S/LAKE, DCK, OSERIAN, OLKARIADATE: Thursday 04.06.2015  TIME: 9.00 AM - 5.00 PMWhole of DCK area, Vegro Farm, Finlay Kingffisher, Rift Farm, Vadenbarg Farm, Longonot Horticulture & Longonot Farm, Kedong Farm, Finlay Flamingo, Nini Farm, Kamuta Farm, Sanctuary Farm, Sopa Lodge, Sawela Lodge, Simba Lodge, Finlay Kingffischer, Sir Karuturi Farm, Sera Farm, Kentaria, Double Dutch, Agri, Bio Ltd, Orpower Housing Estate, Kengen Houses, Fish Eagle, Kwa Muya Centre, Kamere Centre, Whole of Oserian both 33kV & 11kV, Whole of Olkaria, Kongoni Centre, Maela Entre, DURO Farm, Aquilla Farm, Kijabe Ltd, Ndabibi Centre, Hindu Farm, Crater Lake, Hippo Point, Kinja Estate, Kongoni Lodge, Tharau area, Mirera area, Longonot Gate
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\SiJZCKltLh6S_Interuptions 28.05.2015.pdf
# PIAVE, PART OF NJORO TOWN, OGILGEIDATE: Tuesday 02.06.2015  TIME 9.00AM - 5.00 P.M.Whole of Piave Centre, Ngata Centre, Ogilgei Centre, Part of Njoro Town, Kerma, Dr Sally Kosgei Flower Farm, Njoro Precious Girls, Bright Light Girls, Bridgewater Girls, Lord Egerton Castle, RVIST, Kokoto Ltd, Jesus is Lord Radio, Tumaini Cortages, Rhoda Sisal, Kapkures, Lalwet, Ingobor, Baraka Estate, Njoro Police, Rumwe
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\SO1FJhQKZLyt_Interruptions 21 04 2016.pdf
# MASII, MBOONIDATE: Friday 29.04.2016fi Time: 8.00 A.M. - 5.00 P.M.fiMasii, Wamunyu, Katangi, Tawa, Kikima, Utangwa, Mbumbuni, Yathui
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# ffi
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# fiPART OF KISAUNIDATE: Tuesday 17.05.2016  TIME: 9.00 - 5.00 P.M.Kangi, Makaburini, Super Bandika, Kongowea Mkt
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# PART OF MIRITINIDATE: Thursday 19.05.2016  TIME: 9.00 - 5.00 P.M.Endi Textile, Hakika, Transpares, TSS
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# KISAUNI, MUSHOMORONIDATE: Friday 20.05.2016  TIME: 9.00 - 5.00 P.M.Kisauni, Mushomoroni, Nyali, Ratna Square
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# MTONGWEDATE: Friday 20.05.2016  TIME: 9.00 - 5.00 P.M.Mtongwe, Kenya Navy
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# PART OF MAZERAS, MARIAKANIDATE: Tuesday 17.05.2016  TIME: 9.00 - 5.00 P.M.Danka P/Stn, PN Mashru, Bofa Parts of Mazeras Town, Kasemeni
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# PART OF BAMBA, RABAIDATE: Tuesday 17.05.2016  TIME: 9.00 - 5.00 P.M.Bamba, Tsangasini, Bamba Dispensary
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# PARTS OF KANAMAIDATE: Wednesday 18.05.2016  TIME: 9.00 - 5.00 P.M.Kanamai, Khosla Farm, KARI
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\TWVC0N5RpLvL_Interruptions 12 05 2016.pdf
# KWALE DIANIDATE: Friday 20.05.2016  TIME: 9.00 - 5.00 P.M.Kinango, Ngozini, Shimba Hills Game Reserve
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\VyTJbilP8O5r_Interruptions_16.01.2014.pdf
# Factory, Kangari Mkt, Kigumo Mkt, Githambo T/Factory, Kangema Town, Kanyenyaini Tea Factory, Karatu, Gakoe, Gitwe, Kanyoni, Gatura, Kimandi, Ndekei, Ngorongo, Kangari, Muthithi, Githambo, Hon SK Macharia's Residence, Githambo Tea Factory, Mugoiri Sch & Mission, Njumbi High Sch, Iyego, Gakurwe Mkt
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\VyTJbilP8O5r_Interruptions_16.01.2014.pdf
# fl
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\VyTJbilP8O5r_Interruptions_30.01.2014.pdf
# PART OF NAIVASHA ROADDATE: Thursday 06.02.2014  TIME: 9.00 - 5.00 P.M.Part of Gitanga Rd, Hatheru Rd, Kingara Rd, Part of Riara Rd, Riara Close, Mbaazi Ave, Kawangware, Part of Ndwaru Rd, Gathondeki, Precious Blood Riruta
# ----------------------------
# day is out of range for month
# C:\GridWatch\Parsing service interruptions\Readable pdfs\VyTJbilP8O5r_Interruptions_30.01.2014.pdf
# MAWAWA MARKET, GEKONGEDATE: Thursday 30.02.2014  TIME: 9.00 A.M. - 3.00 P.M.Mawawa Mkt, Gekonge Sec/Mkt, Esamba Mkt, Riomego Mkt
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\we5wTxwomcQg_Interruptions - 13.10.2016.pdf
# TUMUTUMU, NGORANO, KIAMARIGADATE: Tuesday 18.10.2016                                       TIME: 800 A.M. - 4.30 P.M.Tumutumu Hosp, Kiangoma, Thaithi, Mathaithi Special Sch, Mugambi, Wakamata, Ngandu, Rititi, Hiriga, Ngaini Macadamia  Gatung'ang'a, Cieni, Mikundi, Kaagati, Ruthagati, Kiamariga, Nyana, Iruri, Muutaga, State Lodge, Kiawarigi, Itiati, Kiamucheru, Kihuri
# ----------------------------
# time data '20-08-17 8:30 AM' does not match format '%Y-%m-%d %I:%M %p'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Yi1WHVM4lYd5_Interruption - Thurs - 11.08.2016.pdf
# MIKINDURI TOWNDATE: Wednesday 17.08.20                       TIME: 8.30 A.M. - 4.30 P.M.Kunati Mkt, Mlango Mkt, Kiguchwa Mkt, Mikinduri Girls, Mikinduri, Kiliene Boarding, Ametho Boarding, MCK Church, Karatina, Kaathi Mkt, Akaiga Sec, Mikinduri, Amatu, Irindiro Mkt, Athwana Cattle Dip, Ankamia Mkt
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\Yjs1c7OWPpWJ_Interruptions 22.10.2015.pdf
# fi
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\zfinszqf2wyE_Interuptions  18.02.2016.pdf
# ff
# ----------------------------
# 'NoneType' object has no attribute 'end'
# C:\GridWatch\Parsing service interruptions\Readable pdfs\zfinszqf2wyE_Interuptions  18.02.2016.pdf
# SOTIK TOWN, NYANSIONGO, KAPLONG MARKETDATE: Monday, 22.02.2016fi fififififififi TIME: 9.00 AM. - 3.00 P.M.Kapkatet Mkt, Kapkatet District Hospital, Tengecha Schools, Kapkatet Tea Factory, Chelilis, Tumbelyon, Kamirai Schools, Kaplong Mkt, Kaplong National Oil, Kaplong Mission Hospital, Ajiwa Shamji LTD, Sotik Water Supply, Chemagel Mkt, New KCC Sotik, Tembwo Mkt, Kibatit, TMC, Chebilat Mkt, Simbi Farm, Nyasiongo Tea Factory, Metamaywa, Kijauri Mkt, Manga Mkt, Manga Engoto, Kahawa, Ndanai Mkt, Gelegele Mkt, Makutano Junction, Kiricha, Oldebesi, Njipship Mkt, Gorgor Mkt, Chebole Mkt, Soimet Mkt, Tarakwa, Birirbei, Sotik Tea Factory, Kipkebe Ltd, Kapletundo Market
# ----------------------------
# substring not found
# C:\GridWatch\Parsing service interruptions\Readable pdfs\zzUCNfUVvfhS_Interruptions 08.01.2015.pdf
# LANGATA, OTIENDEDATE: Friday 16.01.2015Otiende, Onyoka Estate, St Mary's Hospital, Langata High School, Langata Women GK Prison
# ----------------------------
# finish
